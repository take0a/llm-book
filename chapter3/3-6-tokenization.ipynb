# %% [markdown]
# # 第3章 大規模言語モデルの基礎

# %% [markdown]
# ## 3.6 トークナイゼーション

# %% [markdown]
# ### 3.6.1 バイト対符号化

# %%
# 単語とその頻度
word_freqs = {
    "たのしい": 6,
    "たのしさ": 2,
    "うつくしい": 4,
    "うつくしさ": 1,
}
# 語彙を文字で初期化
vocab = sorted(set([char for word in word_freqs for char in word]))
# 単語とその分割状態
splits = {word: [char for char in word] for word in word_freqs}

# %%
from collections import Counter

def compute_most_frequent_pair(
    splits: dict[str, list[str]]
) -> tuple[str, str]:
    """
    最も頻度の高い隣接するサブワードの組を計算する
    """
    pair_freqs = Counter()  # サブワードの組のカウンタ
    for word, freq in word_freqs.items():  # すべての単語を処理
        split = splits[word]  # 現在の単語の分割状態を取得
        # すべての隣接したサブワードの組を処理
        for i in range(len(split) - 1):
            pair = (split[i], split[i + 1])
            # サブワードの組の頻度に単語の頻度を加算
            pair_freqs[pair] += freq
    # カウンタから最も頻度の高いサブワードの組を取得
    pair, _ = pair_freqs.most_common(1)[0]
    return pair

def merge_pair(
    target_pair: tuple[str, str], splits: dict[str, list[str]]
) -> dict[str, list[str]]:
    """
    サブワードの組を結合する
    """
    l_str, r_str = target_pair
    for word in word_freqs:  # すべての単語を処理
        split = splits[word]  # 現在の単語の分割状態を取得
        i = 0
        # すべての隣接したサブワードの組を処理
        while i < len(split) - 1:
            # サブワードの組が結合対象と一致したら結合
            if split[i] == l_str and split[i + 1] == r_str:
                split = split[:i] + [l_str + r_str] + split[i + 2 :]
            i += 1
        splits[word] = split  # 現在の結合状態を更新
    return splits

# %%
for step in range(9):
    # 最も頻度の高い隣接するサブワードの組を計算
    target_pair = compute_most_frequent_pair(splits)
    # サブワードの組を結合
    splits = merge_pair(target_pair, splits)
    # 語彙にサブワードの組を追加
    vocab.append(target_pair)

# %%
print(vocab)
# Out:
# ['い', 'う', 'く', 'さ', 'し', 'た', 'つ', 'の', ('し', 'い'), ('た', 'の'), ('たの', 'しい'), ('う', 'つ'), ('うつ', 'く'), ('うつく', 'しい'), ('し', 'さ'), ('たの', 'しさ'), ('うつく', 'しさ')]

# %% [markdown]
# ### 3.6.3 日本語の扱い

# %%
# !pip install transformers[ja,sentencepiece,torch]
# Out:
# Requirement already satisfied: transformers[ja,sentencepiece,torch] in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (4.39.3)
# Requirement already satisfied: filelock in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (3.13.4)
# Requirement already satisfied: pyyaml>=5.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (6.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (0.4.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (2023.12.25)
# Requirement already satisfied: requests in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (2.31.0)
# Requirement already satisfied: tqdm>=4.27 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (4.66.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (0.15.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (0.22.2)
# Requirement already satisfied: packaging>=20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (23.1)
# Requirement already satisfied: numpy>=1.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (1.26.4)
# Requirement already satisfied: torch in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (2.2.2)
# Requirement already satisfied: accelerate>=0.21.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (0.29.2)
# Requirement already satisfied: protobuf in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (5.26.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (0.2.0)
# Requirement already satisfied: rhoknp<1.3.1,>=1.1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (1.3.0)
# Requirement already satisfied: fugashi>=1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (1.3.1)
# Requirement already satisfied: ipadic<2.0,>=1.0.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (1.0.0)
# Requirement already satisfied: unidic>=1.0.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (1.1.0)
# Requirement already satisfied: unidic-lite>=1.0.7 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (1.0.8)
# Requirement already satisfied: sudachidict-core>=20220729 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (20240409)
# Requirement already satisfied: sudachipy>=0.6.6 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers[ja,sentencepiece,torch]) (0.6.8)
# Requirement already satisfied: psutil in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from accelerate>=0.21.0->transformers[ja,sentencepiece,torch]) (5.9.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[ja,sentencepiece,torch]) (4.11.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[ja,sentencepiece,torch]) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (12.1.105)
# Requirement already satisfied: sympy in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (1.12)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (2.2.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (12.1.3.1)
# Requirement already satisfied: networkx in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (3.2.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (2.19.3)
# Requirement already satisfied: jinja2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (3.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch->transformers[ja,sentencepiece,torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[ja,sentencepiece,torch]) (12.4.127)
# Requirement already satisfied: wasabi<1.0.0,>=0.6.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from unidic>=1.0.2->transformers[ja,sentencepiece,torch]) (0.10.1)
# Requirement already satisfied: plac<2.0.0,>=1.1.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from unidic>=1.0.2->transformers[ja,sentencepiece,torch]) (1.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers[ja,sentencepiece,torch]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers[ja,sentencepiece,torch]) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers[ja,sentencepiece,torch]) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers[ja,sentencepiece,torch]) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from jinja2->torch->transformers[ja,sentencepiece,torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sympy->torch->transformers[ja,sentencepiece,torch]) (1.3.0)

# %%
from transformers import AutoTokenizer

mbert_tokenizer = AutoTokenizer.from_pretrained(
    "bert-base-multilingual-cased"
)
print(mbert_tokenizer.tokenize("自然言語処理"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# ['自', '然', '言', '語', '処', '理']

# %%
print(mbert_tokenizer.tokenize("自然言語処理にディープラーニングを使う"))
# Out:
# ['自', '然', '言', '語', '処', '理', 'に', '##ディ', '##ープ', '##ラー', '##ニング', '##を', '使', 'う']

# %%
xlmr_tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-base")
print(xlmr_tokenizer.tokenize("自然言語処理にディープラーニングを使う"))
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# ['▁', '自然', '言語', '処理', 'に', 'ディー', 'プラ', 'ー', 'ニング', 'を使う']

# %%
print(xlmr_tokenizer.tokenize("私は日本で生まれました"))
# Out:
# ['▁私は', '日本で', '生まれ', 'ました']

# %%
print(xlmr_tokenizer.tokenize("本日はよろしくお願いいたします"))
# Out:
# ['▁本', '日は', 'よろしくお願いいたします']

# %%
bert_ja_tokenizer = AutoTokenizer.from_pretrained(
    "cl-tohoku/bert-base-japanese-v3"
)
print(
    bert_ja_tokenizer.tokenize("自然言語処理にディープラーニングを使う")
)
# Out:
# ['自然', '言語', '処理', 'に', 'ディープ', 'ラー', '##ニング', 'を', '使う']

# %%
print(bert_ja_tokenizer.tokenize("私は日本で生まれました"))
# Out:
# ['私', 'は', '日本', 'で', '生まれ', 'まし', 'た']
